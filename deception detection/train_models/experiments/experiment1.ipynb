# %%
conda install -c conda-forge sox
# Out:
# Channels:
#  - conda-forge
#  - defaults
#  - anaconda
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda/envs/jupyter_env
#
#   added / updated specs:
#     - sox
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2025.1.31          |     pyhd8ed1ab_0         159 KB  conda-forge
#     gettext-0.23.1             |       h5888daf_0         473 KB  conda-forge
#     gettext-tools-0.23.1       |       h5888daf_0         2.8 MB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     libasprintf-0.23.1         |       h8e693c7_0          42 KB  conda-forge
#     libasprintf-devel-0.23.1   |       h8e693c7_0          33 KB  conda-forge
#     libflac-1.4.3              |       h59595ed_0         385 KB  conda-forge
#     libgettextpo-0.23.1        |       h5888daf_0         163 KB  conda-forge
#     libgettextpo-devel-0.23.1  |       h5888daf_0          36 KB  conda-forge
#     liblzma-5.6.4              |       hb9d3cd8_0         109 KB  conda-forge
#     liblzma-devel-5.6.4        |       hb9d3cd8_0         370 KB  conda-forge
#     libogg-1.3.5               |       h4ab18f5_0         201 KB  conda-forge
#     libopus-1.3.1              |       h7f98852_1         255 KB  conda-forge
#     libpng-1.6.47              |       h943b412_0         282 KB  conda-forge
#     libsndfile-1.2.2           |       hc60ed4a_1         346 KB  conda-forge
#     libvorbis-1.3.7            |       h9c3ff4c_0         280 KB  conda-forge
#     mad-0.15.1b                |       h9c3ff4c_1         113 KB  conda-forge
#     mpg123-1.32.9              |       hc50e24c_0         480 KB  conda-forge
#     openssl-3.4.1              |       h7b32b05_0         2.8 MB  conda-forge
#     sox-14.4.2                 |    h59a48fd_1020         496 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        10.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   gettext            conda-forge/linux-64::gettext-0.23.1-h5888daf_0
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.23.1-h5888daf_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   libasprintf        conda-forge/linux-64::libasprintf-0.23.1-h8e693c7_0
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.23.1-h8e693c7_0
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.23.1-h5888daf_0
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.23.1-h5888daf_0
#   liblzma            conda-forge/linux-64::liblzma-5.6.4-hb9d3cd8_0
#   liblzma-devel      conda-forge/linux-64::liblzma-devel-5.6.4-hb9d3cd8_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-h4ab18f5_0
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libpng             conda-forge/linux-64::libpng-1.6.47-h943b412_0
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   mad                conda-forge/linux-64::mad-0.15.1b-h9c3ff4c_1
#   mpg123             conda-forge/linux-64::mpg123-1.32.9-hc50e24c_0
#   sox                conda-forge/linux-64::sox-14.4.2-h59a48fd_1020
#
# The following packages will be UPDATED:
#
#   openssl                                  3.3.2-hb9d3cd8_0 --> 3.4.1-h7b32b05_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/linux-64::certifi-2025.1.31~ --> conda-forge/noarch::certifi-2025.1.31-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# gettext-tools-0.23.1 | 2.8 MB    |                                       |   0%
# openssl-3.4.1        | 2.8 MB    |                                       |   0%
#
# lame-3.100           | 496 KB    |                                       |   0%
#
#
# sox-14.4.2           | 496 KB    |                                       |   0%
#
#
#
# mpg123-1.32.9        | 480 KB    |                                       |   0%
#
#
#
#
# gettext-0.23.1       | 473 KB    |                                       |   0%
#
#
#
#
#
# libflac-1.4.3        | 385 KB    |                                       |   0%
#
#
#
#
#
#
# liblzma-devel-5.6.4  | 370 KB    |                                       |   0%
#
#
#
#
#
#
#
# libsndfile-1.2.2     | 346 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libpng-1.6.47        | 282 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libvorbis-1.3.7      | 280 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libopus-1.3.1        | 255 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libogg-1.3.5         | 201 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-0.23.1  | 163 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.1.31    | 159 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mad-0.15.1b          | 113 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.6.4        | 109 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-0.23.1   | 42 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-devel-0 | 36 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gettext-tools-0.23.1 | 2.8 MB    | 8                                     |   2%
#
#
# sox-14.4.2           | 496 KB    | #1                                    |   3%
# openssl-3.4.1        | 2.8 MB    | 2                                     |   1%
#
#
#
#
# gettext-0.23.1       | 473 KB    | #2                                    |   3%
#
#
#
#
#
# libflac-1.4.3        | 385 KB    | #5                                    |   4%
#
#
#
# mpg123-1.32.9        | 480 KB    | ##################################### | 100%
#
#
#
# mpg123-1.32.9        | 480 KB    | ##################################### | 100%
#
#
#
#
#
#
# gettext-tools-0.23.1 | 2.8 MB    | ################################8     |  89%
#
#
#
#
#
#
#
# libsndfile-1.2.2     | 346 KB    | #7                                    |   5%
#
#
# sox-14.4.2           | 496 KB    | ##################################### | 100%
#
#
# sox-14.4.2           | 496 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libpng-1.6.47        | 282 KB    | ##                                    |   6%
#
#
#
#
#
#
#
#
#
# libvorbis-1.3.7      | 280 KB    | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
# libopus-1.3.1        | 255 KB    | ##3                                   |   6%
#
# lame-3.100           | 496 KB    | ##################################### | 100%
#
# lame-3.100           | 496 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-0.23.1  | 163 KB    | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# libogg-1.3.5         | 201 KB    | ##9                                   |   8%
#
#
#
#
#
# libflac-1.4.3        | 385 KB    | ##################################### | 100%
#
#
#
#
#
# libflac-1.4.3        | 385 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mad-0.15.1b          | 113 KB    | #####2                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.1.31    | 159 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-0.23.1   | 42 KB     | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.6.4        | 109 KB    | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-devel-0 | 36 KB     | ################4                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-devel-0. | 33 KB     | #################6                    |  48%
#
#
#
#
#
#
#
# libsndfile-1.2.2     | 346 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libsndfile-1.2.2     | 346 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libpng-1.6.47        | 282 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libpng-1.6.47        | 282 KB    | ##################################### | 100%
#
#
#
#
#
#
# liblzma-devel-5.6.4  | 370 KB    | ##################################### | 100%
#
#
#
#
#
#
# liblzma-devel-5.6.4  | 370 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libvorbis-1.3.7      | 280 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libvorbis-1.3.7      | 280 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libopus-1.3.1        | 255 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# gettext-tools-0.23.1 | 2.8 MB    | ##################################### | 100%
# openssl-3.4.1        | 2.8 MB    | ##################################### | 100%
# openssl-3.4.1        | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-0.23.1  | 163 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-0.23.1  | 163 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mad-0.15.1b          | 113 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mad-0.15.1b          | 113 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.1.31    | 159 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2025.1.31    | 159 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libogg-1.3.5         | 201 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libogg-1.3.5         | 201 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-0.23.1   | 42 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-0.23.1   | 42 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-devel-0 | 36 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgettextpo-devel-0 | 36 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.6.4        | 109 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.6.4        | 109 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-devel-0. | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libasprintf-devel-0. | 33 KB     | ##################################### | 100%
#
#
#
#
# gettext-0.23.1       | 473 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchaudio pandas numpy sklearn librosa efficientnet-pytorch
# Out:
# Requirement already satisfied: torch in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (1.13.0)
# Requirement already satisfied: torchaudio in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (0.13.0)
# Requirement already satisfied: pandas in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: numpy in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (1.26.4)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torchaudio
from torch.utils.data import Dataset, DataLoader
import glob
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score
import torchaudio.transforms as T
from torchvision.models import resnet18, resnet34, efficientnet_b0
import torch.nn.functional as F

# Alternative implementation for time stretching and pitch shifting
def time_stretch(waveform, sample_rate, rate):
    """Time stretch without changing pitch using torchaudio's speed effect"""
    effect = [["speed", str(rate)]]
    return torchaudio.sox_effects.apply_effects_tensor(waveform.unsqueeze(0), sample_rate, effect)[0]

def pitch_shift(waveform, sample_rate, n_steps):
    """Pitch shift using torchaudio's pitch effect"""
    effect = [["pitch", str(n_steps * 100)]]
    return torchaudio.sox_effects.apply_effects_tensor(waveform.unsqueeze(0), sample_rate, effect)[0]

# Enhanced Audio Dataset with Advanced Augmentations
class AudioDataset(Dataset):
    def __init__(self, annotations_file, audio_dir, target_length=16000, augmentations=False, use_spectrogram=False):
        self.annos = pd.read_csv(annotations_file)
        self.audio_dir = audio_dir
        self.target_length = target_length
        self.augmentations = augmentations
        self.use_spectrogram = use_spectrogram
        self.spec_aug = nn.Sequential(
            T.TimeMasking(time_mask_param=40),
            T.FrequencyMasking(freq_mask_param=27)
        ) if augmentations else None

        self.valid_data = []
        for idx in range(len(self.annos)):
            clip_name = self.annos.iloc[idx, 0]
            audio_path = os.path.join(self.audio_dir, f"{clip_name}.wav")
            if os.path.exists(audio_path):
                label = self._process_label(self.annos.iloc[idx, 1])
                self.valid_data.append((audio_path, label))

        print(f"Found {len(self.valid_data)}/{len(self.annos)} valid files.")

    def __len__(self):
        return len(self.valid_data)

    def __getitem__(self, idx):
        audio_path, label = self.valid_data[idx]
        try:
            waveform, sample_rate = torchaudio.load(audio_path)
            waveform = waveform.mean(dim=0)  # Convert to mono
            waveform = torchaudio.functional.resample(waveform, sample_rate, 16000)

            if waveform.shape[0] > self.target_length:
                waveform = waveform[:self.target_length]
            else:
                padding = self.target_length - waveform.shape[0]
                waveform = torch.nn.functional.pad(waveform, (0, padding))

            if self.use_spectrogram:
                spectrogram = T.MelSpectrogram(
                    sample_rate=16000,
                    n_mels=256,
                    n_fft=2048,
                    hop_length=512
                )(waveform)
                spectrogram = T.AmplitudeToDB()(spectrogram)

                if self.augmentations:
                    spectrogram = self.spec_aug(spectrogram)
                    if torch.rand(1) < 0.3:
                        waveform = time_stretch(waveform, 16000, 1.2)
                    if torch.rand(1) < 0.3:
                        waveform = pitch_shift(waveform, 16000, 4)

                spectrogram = spectrogram.unsqueeze(0)
                return spectrogram.float(), torch.tensor(label)
            else:
                if self.augmentations:
                    waveform = self._enhanced_waveform_augmentations(waveform)
                return waveform.float(), torch.tensor(label)
        except Exception as e:
            print(f"Error loading {audio_path}: {e}")
            return None, None

    def _enhanced_waveform_augmentations(self, waveform):
        if torch.rand(1) < 0.5:
            time_mask = T.TimeMasking(time_mask_param=100)
            waveform = time_mask(waveform.unsqueeze(0)).squeeze(0)
        if torch.rand(1) < 0.3:
            noise = torch.randn_like(waveform) * 0.01
            waveform += noise
        return waveform

    def _process_label(self, label_str):
        str_label = str(label_str).strip().lower()
        return 0 if any(k in str_label for k in ['truth', '0']) else 1

# Collate Function with Mixup Support
def audio_collate_fn(batch):
    batch = [item for item in batch if item[0] is not None]
    if not batch:
        return torch.zeros(1, 16000), torch.tensor([0])
    inputs, labels = zip(*batch)
    if isinstance(inputs[0], torch.Tensor):
        inputs = torch.stack(inputs)
    labels = torch.stack(labels)
    return inputs, labels

def mixup_data(x, y, alpha=0.4):
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

# Model Architectures
class ASTModel(nn.Module):
    def __init__(self, patch_size=16, num_layers=6, num_heads=8, embed_dim=768):
        super().__init__()
        self.patch_size = patch_size
        self.patch_embed = nn.Conv2d(1, embed_dim, kernel_size=patch_size, stride=patch_size)
        
        # Calculate dynamic dimensions based on input
        self.dynamic_pos_embed = True
        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=embed_dim, nhead=num_heads), 
            num_layers=num_layers
        )
        self.classifier = nn.Linear(embed_dim, 2)

    def forward(self, x):
        # x shape: [batch, 1, n_mels, time_steps]
        x = self.patch_embed(x)  # [batch, embed_dim, n_patches_mel, n_patches_time]
        
        # Calculate the number of patches
        b, c, h, w = x.shape
        x = x.flatten(2).transpose(1, 2)  # [batch, n_patches, embed_dim]
        
        # Dynamic position embedding
        if self.dynamic_pos_embed:
            pos_embed = nn.Parameter(torch.zeros(1, x.shape[1] + 1, c)).to(x.device)
            nn.init.trunc_normal_(pos_embed, std=0.02)
        else:
            pos_embed = self.pos_embed
            
        cls_tokens = self.cls_token.expand(b, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + pos_embed
        
        x = self.transformer(x)
        pooled = x[:, 0]  # CLS token
        return self.classifier(pooled)

class EfficientNetModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.effnet = efficientnet_b0(pretrained=True)
        self.effnet.features[0][0] = nn.Conv2d(1, 32, kernel_size=3, stride=2, padding=1, bias=False)
        self.effnet.classifier[1] = nn.Linear(self.effnet.classifier[1].in_features, 2)

    def forward(self, x):
        return self.effnet(x)

class CRNNModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
        )
        self.gru = nn.GRU(128 * 64, 256, bidirectional=True, dropout=0.3)
        self.fc = nn.Linear(512, 2)

    def forward(self, x):
        x = self.cnn(x)
        b, c, h, w = x.size()
        x = x.view(b, c * h, w).permute(0, 2, 1)
        x, _ = self.gru(x)
        x = x.mean(dim=1)
        return self.fc(x)

class PANNModel(nn.Module):
    def __init__(self, num_classes=2):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(256, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

# Advanced Loss Functions
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        loss = self.alpha * (1 - pt) ** self.gamma * ce_loss
        return loss.mean()

# Training Function with Advanced Features
def train_model(config, fold):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using {device} for fold {fold}")
    
    # Get fold-specific file paths
    train_file = os.path.join(config['protocols_dir'], f"train_fold{fold}.csv")
    test_file = os.path.join(config['protocols_dir'], f"test_fold{fold}.csv")
    
    # Model Initialization
    if config['model_type'] == 'ast':
        model = ASTModel(
            patch_size=config.get('patch_size', 16),
            num_layers=config.get('num_layers', 6),
            num_heads=config.get('num_heads', 8),
            embed_dim=config.get('embed_dim', 768)
        ).to(device)
    elif config['model_type'] == 'effnet':
        model = EfficientNetModel().to(device)
    elif config['model_type'] == 'crnn':
        model = CRNNModel().to(device)
    elif config['model_type'] == 'pann':
        model = PANNModel().to(device)
    else:
        raise ValueError("Invalid model type")

    # Optimizer and Loss
    optimizer = optim.AdamW(
        model.parameters(),
        lr=config['learning_rate'],
        weight_decay=config.get('weight_decay', 0.01)
    )

    if config.get('loss_type') == 'focal':
        criterion = FocalLoss().to(device)
    else:
        class_weights = compute_class_weights(train_file, config['audio_dir']).to(device)
        criterion = nn.CrossEntropyLoss(weight=class_weights if config['class_weighting'] else None)

    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,
        patience=2,
        verbose=True
    )

    # Fold-specific checkpoint directory
    checkpoint_dir = os.path.join(config['checkpoint_dir'], f'fold_{fold}')
    os.makedirs(checkpoint_dir, exist_ok=True)
    metrics_file = os.path.join(checkpoint_dir, 'metrics.csv')
    
    if not os.path.exists(metrics_file):
        pd.DataFrame(columns=['epoch', 'train_loss', 'train_acc', 'train_f1', 'train_recall', 'train_auc',
                              'val_loss', 'val_acc', 'val_f1', 'val_recall', 'val_auc']).to_csv(metrics_file, index=False)

    # Initialize datasets
    train_dataset = AudioDataset(
        train_file,
        config['audio_dir'],
        target_length=config['target_length'],
        augmentations=config['augmentations'],
        use_spectrogram=config['use_spectrogram']
    )
    val_dataset = AudioDataset(
        test_file,
        config['audio_dir'],
        target_length=config['target_length'],
        augmentations=False,
        use_spectrogram=config['use_spectrogram']
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=config['batch_size'],
        collate_fn=audio_collate_fn,
        shuffle=True,
        num_workers=4
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=config['batch_size'],
        collate_fn=audio_collate_fn,
        num_workers=4
    )

    best_val_loss = float('inf')
    patience_counter = 0

    for epoch in range(config['num_epochs']):
        model.train()
        epoch_loss = 0
        train_preds, train_labels = [], []

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            if config.get('use_mixup', False):
                inputs, targets_a, targets_b, lam = mixup_data(inputs, labels)
                outputs = model(inputs)
                loss = lam * criterion(outputs, targets_a) + (1 - lam) * criterion(outputs, targets_b)
            else:
                outputs = model(inputs)
                loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            train_preds.append(outputs.detach())
            train_labels.append(labels)

        # Training metrics
        train_preds = torch.cat(train_preds)
        train_labels = torch.cat(train_labels)
        train_acc, train_f1, train_recall, train_auc = compute_metrics(train_preds, train_labels)
        train_loss = epoch_loss / len(train_loader)

        # Validation
        model.eval()
        val_loss = 0
        val_preds, val_labels = [], []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                val_loss += criterion(outputs, labels).item()
                val_preds.append(outputs)
                val_labels.append(labels)

        val_preds = torch.cat(val_preds)
        val_labels = torch.cat(val_labels)
        val_acc, val_f1, val_recall, val_auc = compute_metrics(val_preds, val_labels)
        val_loss = val_loss / len(val_loader)

        # Update scheduler
        scheduler.step(val_loss)

        # Save metrics
        metrics = {
            'epoch': epoch + 1,
            'train_loss': train_loss,
            'train_acc': train_acc,
            'train_f1': train_f1,
            'train_recall': train_recall,
            'train_auc': train_auc,
            'val_loss': val_loss,
            'val_acc': val_acc,
            'val_f1': val_f1,
            'val_recall': val_recall,
            'val_auc': val_auc
        }
        pd.DataFrame([metrics]).to_csv(metrics_file, mode='a', header=False, index=False)

        # Save best model
        if val_loss < best_val_loss - config['min_delta']:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_loss': val_loss,
            }, os.path.join(checkpoint_dir, 'best_model.pth'))
        else:
            patience_counter += 1
            if patience_counter >= config['patience']:
                print(f"Early stopping at epoch {epoch+1}")
                break

        print(f"Fold {fold} | Epoch {epoch+1}: "
              f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val AUC: {val_auc:.4f}")

def compute_class_weights(train_file, audio_dir):
    annos = pd.read_csv(train_file)
    labels = []
    for idx in range(len(annos)):
        clip_name = annos.iloc[idx, 0]
        audio_path = os.path.join(audio_dir, f"{clip_name}.wav")
        if os.path.exists(audio_path):
            label = 0 if any(k in str(annos.iloc[idx, 1]).lower() for k in ['truth', '0']) else 1
            labels.append(label)
    labels = np.array(labels)
    class_counts = np.bincount(labels)
    total = len(labels)
    weights = total / (2.0 * class_counts)
    return torch.tensor(weights, dtype=torch.float)

def compute_metrics(preds, labels):
    preds = preds.argmax(dim=1).cpu().numpy()
    labels = labels.cpu().numpy()
    acc = accuracy_score(labels, preds)
    f1 = f1_score(labels, preds)
    recall = recall_score(labels, preds)
    auc = roc_auc_score(labels, preds)
    return acc, f1, recall, auc

# Main Execution
if __name__ == "__main__":
    base_config = {
        'batch_size': 16,
        'num_epochs': 50,
        'learning_rate': 1e-3,
        'weight_decay': 0.01,
        'audio_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files',
        'protocols_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/train_protocol',
        'base_checkpoint_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/train_new/experiment1',
        'target_length': 44100,
        'augmentations': True,
        'class_weighting': True,
        'use_spectrogram': True,
        'use_mixup': True,
        'patience': 5,
        'min_delta': 0.001
    }

    experiments = [
        {
            'name': 'effnet_b0_specaug',
            'model_type': 'effnet',
            'learning_rate': 2e-4,
            'batch_size': 32
        },
        {
            'name': 'crnn_advanced',
            'model_type': 'crnn',
            'loss_type': 'focal',
            'target_length': 88200
        },
        {
        'name': 'ast_dynamic',
        'model_type': 'ast',
        'patch_size': 16,  # Can try 8 or 32
        'num_layers': 6,
        'num_heads': 8,
        'embed_dim': 768,
        'target_length': 44100  # Should match your audio length
        },
        {
            'name': 'pann_advanced',
            'model_type': 'pann',
            'batch_size': 32
        }
    ]

    for exp in experiments:
        config = base_config.copy()
        config.update(exp)
        
        # Create parent experiment directory
        exp_checkpoint_dir = os.path.join(base_config['base_checkpoint_dir'], exp['name'])
        os.makedirs(exp_checkpoint_dir, exist_ok=True)
        
        # Run for all 3 folds
        for fold in [1, 2, 3]:
            print(f"\nStarting experiment: {exp['name']} - Fold {fold}")
            config['checkpoint_dir'] = exp_checkpoint_dir
            train_model(config, fold)
            print(f"Completed fold {fold} for experiment: {exp['name']}\n")
# Out:
# Starting experiment: effnet_b0_specaug - Fold 1
# Using cpu for fold 1
# Found 826/1098 valid files.
# Found 435/548 valid files.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_lie_13.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP57_truth_24.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_lie_20.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP25_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_truth14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_truth11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP10_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP6_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_lie9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP21_lie18.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP66_truth_7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP4_truth11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_true6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_lie_24.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP66_truth_15.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_lie18.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP4_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP65_lie_11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_deception_20.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP23_truth3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_truth3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_truth_7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP34_lie10.wav: Input tensor has to be 2D.Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_lie2.wav: Input tensor has to be 2D.
#
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_lie15.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_truth_1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie16.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_lie14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP34_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP9_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_truth2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_truth_19.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP48_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_truth5.wav: Input tensor has to be 2D.
# Fold 1 | Epoch 1: Train Loss: 0.6941 | Val Loss: 0.7198 | Val AUC: 0.5024
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_lie_24.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP4_truth9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_lie_13.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_lie_16.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_21.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP19_lie16.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP75_true3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_truth2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP2_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_truth2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_true2.wav: Input tensor has to be 2D.Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie12.wav: Input tensor has to be 2D.
#
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP11_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_truth13.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie16.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_truth_20.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP27_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP10_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_truth_16.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_truth4.wav: Input tensor has to be 2D.Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_12.wav: Input tensor has to be 2D.
#
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP19_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP17_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_truth11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP57_truth_6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_lie14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_lie_18.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_9.wav: Input tensor has to be 2D.Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_lie14.wav: Input tensor has to be 2D.
#
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP20_lie9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_lie_30.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP24_lie14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP48_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP27_truth10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth22.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_truth_6.wav: Input tensor has to be 2D.
# Fold 1 | Epoch 2: Train Loss: 0.6771 | Val Loss: 0.7213 | Val AUC: 0.5179
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP34_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP21_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_truth_5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP4_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_truth11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP5_truth9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP32_truth2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_truth3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_truth_6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP5_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP9_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP66_lie_11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_truth_6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_truth_9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP32_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_lie_8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP4_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP6_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_truth11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP25_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie16.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_truth_1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_20.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_21.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP2_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_truth3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_lie_4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP23_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_truth3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP20_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_23.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP21_lie18.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP2_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_lie17.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_truth_20.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_truth9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP10_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth13.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP32_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_truth_13.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP66_lie_10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP48_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP2_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP4_lie1.wav: Input tensor has to be 2D.
# Fold 1 | Epoch 3: Train Loss: 0.6551 | Val Loss: 0.7156 | Val AUC: 0.5177
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_lie_11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_truth_18.wav: Input tensor has to be 2D.Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_truth8.wav: Input tensor has to be 2D.
#
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_lie_14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP6_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth17.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP19_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP10_truth2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_23.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_truth9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP10_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP32_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP17_truth11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP75_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP25_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP6_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_truth2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP34_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP75_true3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP11_lie9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP36_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP6_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP48_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie16.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_lie_5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_lie_11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP32_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie17.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP9_lie17.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_truth_12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_lie_32.wav: Input tensor has to be 2D.Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_truth5.wav: Input tensor has to be 2D.
#
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP48_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_22.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_truth_4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_lie8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP48_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_truth11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie8.wav: Input tensor has to be 2D.
# Fold 1 | Epoch 4: Train Loss: 0.6517 | Val Loss: 0.7178 | Val AUC: 0.5407
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_lie_23.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_truth13.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_truth_11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_lie17.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_truth13.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_truth_5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie9.wav: Input tensor has to be 2D.Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP21_lie16.wav: Input tensor has to be 2D.
#
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_lie_24.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP19_truth3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth24.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP27_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_lie18.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP66_truth_7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_lie_10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie20.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP75_true3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP24_lie17.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth8.wav: Input tensor has to be 2D.
# ...
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP24_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_truth11.wav: Input tensor has to be 2D.Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_lie2.wav: Input tensor has to be 2D.
#
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP24_lie13.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_truth10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP19_lie14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_lie10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP5_truth2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP20_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_lie_14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP5_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_truth2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true10.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_truth_7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP65_truth_4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_true9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP32_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP57_truth_29.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP75_true3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP34_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_deception_21.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth16.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_truth8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_truth7.wav: Input tensor has to be 2D.
# Fold 3 | Epoch 9: Train Loss: 0.6896 | Val Loss: 0.6843 | Val AUC: 0.5613
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP9_lie18.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth15.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_truth12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_lie8.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP9_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_lie_9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_truth_9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP65_truth_1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP9_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_lie12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP21_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_lie1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_lie9.wav: Input tensor has to be 2D.Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP66_truth_8.wav: Input tensor has to be 2D.
#
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP4_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP5_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_truth_12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP20_lie13.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie25.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP38_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_truth2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_12.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_truth9.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP19_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_truth5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie15.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP23_truth6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP11_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_truth3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_lie_15.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie27.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_lie_15.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie14.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP36_truth1.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true18.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP20_lie5.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_lie6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP6_lie3.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_lie18.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP11_truth4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie7.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP65_truth_6.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_lie4.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_lie11.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_lie2.wav: Input tensor has to be 2D.
# Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_lie6.wav: Input tensor has to be 2D.
# Early stopping at epoch 10
# Completed fold 3 for experiment: pann_advanced
