# %%
import sys
print(sys.executable)  # Shows current Python path
# !python --version
# !conda --version  # If conda is installed
# Out:
# /anaconda/envs/jupyter_env/bin/python3.10
# Python 3.10.11
# conda 24.7.1

# %%
# Create a new conda environment (if needed)
# %conda create -n audio_ml python=3.9 -y

# Activate it (may not work in all notebook environments)
# %conda activate audio_ml

# Install PyTorch and dependencies
# %conda install pytorch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2 cudatoolkit=11.7 -c pytorch -y
# %conda install numpy==1.23.5 librosa==0.10.0 scikit-learn==1.2.2 pandas==1.5.3 -y
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda/envs/audio_ml
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     ld_impl_linux-64-2.40      |       h12ee557_0         710 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     ncurses-6.4                |       h6a678d5_0         914 KB
#     openssl-3.0.16             |       h5eee18b_0         5.2 MB
#     pip-25.0                   |   py39h06a4308_0         2.3 MB
#     python-3.9.21              |       he870216_1        25.1 MB
#     readline-8.2               |       h5eee18b_0         357 KB
#     setuptools-75.8.0          |   py39h06a4308_0         1.6 MB
#     sqlite-3.45.3              |       h5eee18b_0         1.2 MB
#     tk-8.6.14                  |       h39e8969_0         3.4 MB
#     tzdata-2025a               |       h04d1e81_0         117 KB
#     wheel-0.45.1               |   py39h06a4308_0         114 KB
#     xz-5.6.4                   |       h5eee18b_1         567 KB
#     zlib-1.2.13                |       h5eee18b_1         111 KB
#     ------------------------------------------------------------
#                                            Total:        52.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2025.2.25-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.40-h12ee557_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-3.0.16-h5eee18b_0
#   pip                pkgs/main/linux-64::pip-25.0-py39h06a4308_0
#   python             pkgs/main/linux-64::python-3.9.21-he870216_1
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-75.8.0-py39h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   tzdata             pkgs/main/noarch::tzdata-2025a-h04d1e81_0
#   wheel              pkgs/main/linux-64::wheel-0.45.1-py39h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.6.4-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
#
# Downloading and Extracting Packages:
# python-3.9.21        | 25.1 MB   |                                       |   0%
# libgcc-ng-11.2.0     | 5.3 MB    |                                       |   0%
#
# openssl-3.0.16       | 5.2 MB    |                                       |   0%
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    |                                       |   0%
#
#
#
# tk-8.6.14            | 3.4 MB    |                                       |   0%
#
#
#
#
# pip-25.0             | 2.3 MB    |                                       |   0%
#
#
#
#
#
# setuptools-75.8.0    | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
# sqlite-3.45.3        | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 710 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# xz-5.6.4             | 567 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libgomp-11.2.0       | 474 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 357 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.4         | 141 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025a         | 117 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 114 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 111 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.9.21        | 25.1 MB   | 9                                     |   3%
# libgcc-ng-11.2.0     | 5.3 MB    | #######                               |  19%
#
# openssl-3.0.16       | 5.2 MB    | ##2                                   |   6%
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | ###2                                  |   9%
#
#
#
# python-3.9.21        | 25.1 MB   | ########                              |  22%
#
# openssl-3.0.16       | 5.2 MB    | ###################################8  |  97%
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | #################################7    |  91%
#
#
#
#
# pip-25.0             | 2.3 MB    | 2                                     |   1%
#
#
#
#
#
# python-3.9.21        | 25.1 MB   | ###################8                  |  54%
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | 6                                     |   2%
#
#
#
#
#
#
# sqlite-3.45.3        | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 710 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
# xz-5.6.4             | 567 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
# python-3.9.21        | 25.1 MB   | ###########################6          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.4         | 141 KB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 357 KB    | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 114 KB    | #####2                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025a         | 117 KB    | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 111 KB    | #####3                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# libgcc-ng-11.2.0     | 5.3 MB    | ##################################### | 100%
# libgcc-ng-11.2.0     | 5.3 MB    | ##################################### | 100%
#
# openssl-3.0.16       | 5.2 MB    | ##################################### | 100%
#
#
#
# tk-8.6.14            | 3.4 MB    | ##################################### | 100%
#
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | ##################################### | 100%
#
#
#
#
# pip-25.0             | 2.3 MB    | ##################################### | 100%
#
#
#
#
# pip-25.0             | 2.3 MB    | ##################################### | 100%
#
#
#
#
#
#
# sqlite-3.45.3        | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
# sqlite-3.45.3        | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 710 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 710 KB    | ##################################### | 100%
#
#
#
#
#
# setuptools-75.8.0    | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
# setuptools-75.8.0    | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# xz-5.6.4             | 567 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# xz-5.6.4             | 567 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libgomp-11.2.0       | 474 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libgomp-11.2.0       | 474 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 357 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 357 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.4         | 141 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.4         | 141 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 114 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 114 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 111 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 111 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 21 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025a         | 117 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025a         | 117 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate audio_ml
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# Note: you may need to restart the kernel to use updated packages.
#
# CondaError: Run 'conda init' before 'conda activate'
#
#
# Note: you may need to restart the kernel to use updated packages.
# Channels:
#  - pytorch
#  - defaults
#  - conda-forge
#  - anaconda
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda/envs/jupyter_env
#
#   added / updated specs:
#     - cudatoolkit=11.7
#     - pytorch==2.0.1
#     - torchaudio==2.0.2
#     - torchvision==0.15.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.5.0                  |       h27087fc_0         2.7 MB  conda-forge
#     blas-1.0                   |              mkl           6 KB
#     cudatoolkit-11.7.1         |      h4bc3d14_13       589.5 MB  conda-forge
#     ffmpeg-5.1.2               | gpl_h8dda1f0_106         9.2 MB  conda-forge
#     filelock-3.13.1            |  py310h06a4308_0          21 KB
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-anaconda-1           |       h8fa9717_0           3 KB
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB
#     freetype-2.13.3            |       h48d6fc4_0         625 KB  conda-forge
#     gmp-6.3.0                  |       h6a678d5_0         608 KB
#     gmpy2-2.2.1                |  py310h5eee18b_0         248 KB
#     gnutls-3.7.9               |       hb077bed_0         1.9 MB  conda-forge
#     intel-openmp-2022.0.1      |    h06a4308_3633         4.2 MB
#     jpeg-9e                    |       h5eee18b_3         262 KB
#     lcms2-2.15                 |       hfd0df8a_0         235 KB  conda-forge
#     lerc-4.0.0                 |       h6a678d5_0         261 KB
#     libblas-3.9.0              |   16_linux64_mkl          13 KB  conda-forge
#     libcblas-3.9.0             |   16_linux64_mkl          12 KB  conda-forge
#     libdeflate-1.17            |       h5eee18b_1          64 KB
#     libdrm-2.4.124             |       hb9d3cd8_0         237 KB  conda-forge
#     libexpat-2.6.4             |       h5888daf_0          72 KB  conda-forge
#     libiconv-1.18              |       h4ce23a2_1         696 KB  conda-forge
#     libidn2-2.3.4              |       h5eee18b_0         146 KB
#     liblapack-3.9.0            |   16_linux64_mkl          12 KB  conda-forge
#     libpciaccess-0.18          |       hd590300_0          28 KB  conda-forge
#     libtasn1-4.19.0            |       h5eee18b_0          63 KB
#     libtiff-4.5.0              |       h6adf6a1_2         397 KB  conda-forge
#     libunistring-0.9.10        |       h27cfd23_0         536 KB
#     libva-2.18.0               |       h0b41bf4_0         182 KB  conda-forge
#     libvpx-1.11.0              |       h295c915_0         1.0 MB
#     libwebp-base-1.3.2         |       h5eee18b_1         425 KB
#     libxcb-1.13                |       h1bed415_1         421 KB
#     libxml2-2.13.7             |       h8d12d68_0         676 KB  conda-forge
#     mkl-2022.1.0               |     hc2b9512_224       129.7 MB
#     mpc-1.3.1                  |       h5eee18b_0         129 KB
#     mpfr-4.2.1                 |       h5eee18b_0         821 KB
#     mpmath-1.3.0               |  py310h06a4308_0         834 KB
#     nettle-3.9.1               |       h7ab15ed_0         988 KB  conda-forge
#     networkx-3.4.2             |  py310h06a4308_0         2.5 MB
#     nomkl-2.0                  |                0           2 KB  anaconda
#     numexpr-2.10.2             |py310hdb6e06b_100         169 KB  conda-forge
#     openh264-2.3.1             |       hcb278e6_2         702 KB  conda-forge
#     openjpeg-2.5.2             |       he7f1fd0_0         371 KB
#     p11-kit-0.24.1             |       hc5aa10d_0         4.5 MB  conda-forge
#     pillow-9.4.0               |  py310h023d228_1        44.3 MB  conda-forge
#     pytorch-2.0.1              |     py3.10_cpu_0        86.2 MB  pytorch
#     pytorch-mutex-1.0          |              cpu           3 KB  pytorch
#     svt-av1-1.4.1              |       hcb278e6_0         2.4 MB  conda-forge
#     sympy-1.13.3               |  py310h06a4308_1        11.3 MB
#     torchaudio-2.0.2           |        py310_cpu         7.3 MB  pytorch
#     torchvision-0.15.2         |        py310_cpu         6.7 MB  pytorch
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xorg-fixesproto-5.0        |    hb9d3cd8_1003          11 KB  conda-forge
#     xorg-kbproto-1.0.7         |    hb9d3cd8_1003          30 KB  conda-forge
#     xorg-libx11-1.8.4          |       h0b41bf4_0         810 KB  conda-forge
#     xorg-libxext-1.3.4         |       h0b41bf4_2          49 KB  conda-forge
#     xorg-libxfixes-5.0.3       |    h7f98852_1004          18 KB  conda-forge
#     xorg-xextproto-7.3.0       |    hb9d3cd8_1004          30 KB  conda-forge
#     xorg-xproto-7.0.31         |    h27cfd23_1007          73 KB
#     ------------------------------------------------------------
#                                            Total:       921.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   aom                conda-forge/linux-64::aom-3.5.0-h27087fc_0
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.7.1-h4bc3d14_13
#   ffmpeg             conda-forge/linux-64::ffmpeg-5.1.2-gpl_h8dda1f0_106
#   filelock           pkgs/main/linux-64::filelock-3.13.1-py310h06a4308_0
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ pkgs/main/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ pkgs/main/noarch::font-ttf-source-code-pro-2.030-hd3eb1b0_0
#   font-ttf-ubuntu    pkgs/main/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   freetype           conda-forge/linux-64::freetype-2.13.3-h48d6fc4_0
#   gmp                pkgs/main/linux-64::gmp-6.3.0-h6a678d5_0
#   gmpy2              pkgs/main/linux-64::gmpy2-2.2.1-py310h5eee18b_0
#   gnutls             conda-forge/linux-64::gnutls-3.7.9-hb077bed_0
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2022.0.1-h06a4308_3633
#   jpeg               pkgs/main/linux-64::jpeg-9e-h5eee18b_3
#   lcms2              conda-forge/linux-64::lcms2-2.15-hfd0df8a_0
#   lerc               pkgs/main/linux-64::lerc-4.0.0-h6a678d5_0
#   libdeflate         pkgs/main/linux-64::libdeflate-1.17-h5eee18b_1
#   libdrm             conda-forge/linux-64::libdrm-2.4.124-hb9d3cd8_0
#   libexpat           conda-forge/linux-64::libexpat-2.6.4-h5888daf_0
#   libiconv           conda-forge/linux-64::libiconv-1.18-h4ce23a2_1
#   libidn2            pkgs/main/linux-64::libidn2-2.3.4-h5eee18b_0
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hd590300_0
#   libtasn1           pkgs/main/linux-64::libtasn1-4.19.0-h5eee18b_0
#   libtiff            conda-forge/linux-64::libtiff-4.5.0-h6adf6a1_2
#   libunistring       pkgs/main/linux-64::libunistring-0.9.10-h27cfd23_0
#   libva              conda-forge/linux-64::libva-2.18.0-h0b41bf4_0
#   libvpx             pkgs/main/linux-64::libvpx-1.11.0-h295c915_0
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.3.2-h5eee18b_1
#   libxcb             pkgs/main/linux-64::libxcb-1.13-h1bed415_1
#   libxml2            conda-forge/linux-64::libxml2-2.13.7-h8d12d68_0
#   mkl                pkgs/main/linux-64::mkl-2022.1.0-hc2b9512_224
#   mpc                pkgs/main/linux-64::mpc-1.3.1-h5eee18b_0
#   mpfr               pkgs/main/linux-64::mpfr-4.2.1-h5eee18b_0
#   mpmath             pkgs/main/linux-64::mpmath-1.3.0-py310h06a4308_0
#   nettle             conda-forge/linux-64::nettle-3.9.1-h7ab15ed_0
#   networkx           pkgs/main/linux-64::networkx-3.4.2-py310h06a4308_0
#   nomkl              anaconda/linux-64::nomkl-2.0-0
#   openh264           conda-forge/linux-64::openh264-2.3.1-hcb278e6_2
#   openjpeg           pkgs/main/linux-64::openjpeg-2.5.2-he7f1fd0_0
#   p11-kit            conda-forge/linux-64::p11-kit-0.24.1-hc5aa10d_0
#   pillow             conda-forge/linux-64::pillow-9.4.0-py310h023d228_1
#   pytorch            pytorch/linux-64::pytorch-2.0.1-py3.10_cpu_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cpu
#   svt-av1            conda-forge/linux-64::svt-av1-1.4.1-hcb278e6_0
#   sympy              pkgs/main/linux-64::sympy-1.13.3-py310h06a4308_1
#   torchaudio         pytorch/linux-64::torchaudio-2.0.2-py310_cpu
#   torchvision        pytorch/linux-64::torchvision-0.15.2-py310_cpu
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-hb9d3cd8_1003
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-hb9d3cd8_1003
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.4-h0b41bf4_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-hb9d3cd8_1004
#   xorg-xproto        pkgs/main/linux-64::xorg-xproto-7.0.31-h27cfd23_1007
#
# The following packages will be UPDATED:
#
#   numexpr            pkgs/main::numexpr-2.10.1-py310hd28fd~ --> conda-forge::numexpr-2.10.2-py310hdb6e06b_100
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2025.1.31~ --> pkgs/main/linux-64::certifi-2025.1.31-py310h06a4308_0
#
# The following packages will be DOWNGRADED:
#
#   blas                                         1.0-openblas --> 1.0-mkl
#   libblas                         3.9.0-16_linux64_openblas --> 3.9.0-16_linux64_mkl
#   libcblas                        3.9.0-16_linux64_openblas --> 3.9.0-16_linux64_mkl
#   liblapack                       3.9.0-16_linux64_openblas --> 3.9.0-16_linux64_mkl
#
#
#
# Downloading and Extracting Packages:
# cudatoolkit-11.7.1   | 589.5 MB  |                                       |   0%
# mkl-2022.1.0         | 129.7 MB  |                                       |   0%
#
# pytorch-2.0.1        | 86.2 MB   |                                       |   0%
#
#
# pillow-9.4.0         | 44.3 MB   |                                       |   0%
#
#
#
# sympy-1.13.3         | 11.3 MB   |                                       |   0%
#
#
#
#
# ffmpeg-5.1.2         | 9.2 MB    |                                       |   0%
#
#
#
#
#
# torchaudio-2.0.2     | 7.3 MB    |                                       |   0%
#
#
#
#
#
#
# torchvision-0.15.2   | 6.7 MB    |                                       |   0%
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 4.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# intel-openmp-2022.0. | 4.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# aom-3.5.0            | 2.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.4.1        | 2.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.11.0        | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.9.1         | 988 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 821 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.4    | 810 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.3.1       | 702 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# mkl-2022.1.0         | 129.7 MB  | 6                                     |   2%
#
# pytorch-2.0.1        | 86.2 MB   | 1                                     |   0%
#
#
# pillow-9.4.0         | 44.3 MB   | 4                                     |   1%
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  |                                       |   0%
# mkl-2022.1.0         | 129.7 MB  | #7                                    |   5%
#
# pytorch-2.0.1        | 86.2 MB   | #8                                    |   5%
#
#
# pillow-9.4.0         | 44.3 MB   | ###4                                  |   9%
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | 2                                     |   1%
# mkl-2022.1.0         | 129.7 MB  | ###1                                  |   8%
#
# pytorch-2.0.1        | 86.2 MB   | ###8                                  |  11%
#
#
# pillow-9.4.0         | 44.3 MB   | #######3                              |  20%
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | 5                                     |   1%
# mkl-2022.1.0         | 129.7 MB  | ####7                                 |  13%
#
# pytorch-2.0.1        | 86.2 MB   | #####7                                |  16%
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | 8                                     |   2%
# mkl-2022.1.0         | 129.7 MB  | ######2                               |  17%
#
# pytorch-2.0.1        | 86.2 MB   | ########2                             |  22%
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #1                                    |   3%
#
# pytorch-2.0.1        | 86.2 MB   | ##########2                           |  28%
#
#
# pillow-9.4.0         | 44.3 MB   | #####################                 |  57%
# mkl-2022.1.0         | 129.7 MB  | #######6                              |  21%
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #4                                    |   4%
#
# pytorch-2.0.1        | 86.2 MB   | ############2                         |  33%
#
#
#
#
# ffmpeg-5.1.2         | 9.2 MB    | ###########7                          |  32%
# mkl-2022.1.0         | 129.7 MB  | #########                             |  24%
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #7                                    |   5%
#
#
#
#
# ffmpeg-5.1.2         | 9.2 MB    | ###########################7          |  75%
#
# pytorch-2.0.1        | 86.2 MB   | ##############                        |  38%
# mkl-2022.1.0         | 129.7 MB  | ##########2                           |  28%
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ##                                    |   5%
#
# pytorch-2.0.1        | 86.2 MB   | ###############9                      |  43%
# mkl-2022.1.0         | 129.7 MB  | ###########5                          |  31%
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ##2                                   |   6%
#
# pytorch-2.0.1        | 86.2 MB   | #################8                    |  48%
# cudatoolkit-11.7.1   | 589.5 MB  | ##5                                   |   7%
#
#
# pillow-9.4.0         | 44.3 MB   | ####################################  |  97%
#
# pytorch-2.0.1        | 86.2 MB   | ###################6                  |  53%
# cudatoolkit-11.7.1   | 589.5 MB  | ##8                                   |   8%
# mkl-2022.1.0         | 129.7 MB  | ###############2                      |  41%
#
# cudatoolkit-11.7.1   | 589.5 MB  | ###                                   |   8%
#
#
#
#
#
# torchaudio-2.0.2     | 7.3 MB    |                                       |   0%
# mkl-2022.1.0         | 129.7 MB  | ################6                     |  45%
#
# cudatoolkit-11.7.1   | 589.5 MB  | ###3                                  |   9%
#
#
#
#
#
# torchaudio-2.0.2     | 7.3 MB    | ####################                  |  54%
# mkl-2022.1.0         | 129.7 MB  | #################9                    |  48%
#
# cudatoolkit-11.7.1   | 589.5 MB  | ###6                                  |  10%
# mkl-2022.1.0         | 129.7 MB  | ###################1                  |  52%
#
# cudatoolkit-11.7.1   | 589.5 MB  | ###8                                  |  10%
# mkl-2022.1.0         | 129.7 MB  | ####################4                 |  55%
#
# cudatoolkit-11.7.1   | 589.5 MB  | ####1                                 |  11%
#
# pytorch-2.0.1        | 86.2 MB   | ##############################5       |  83%
# mkl-2022.1.0         | 129.7 MB  | #####################6                |  59%
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ####3                                 |  12%
#
#
#
#
#
#
# torchvision-0.15.2   | 6.7 MB    | #################3                    |  47%
# mkl-2022.1.0         | 129.7 MB  | ######################7               |  62%
#
# cudatoolkit-11.7.1   | 589.5 MB  | ####6                                 |  13%
#
#
#
#
#
#
# torchvision-0.15.2   | 6.7 MB    | #################################6    |  91%
# mkl-2022.1.0         | 129.7 MB  | #######################8              |  64%
#
# cudatoolkit-11.7.1   | 589.5 MB  | ####8                                 |  13%
#
#
#
#
# ffmpeg-5.1.2         | 9.2 MB    | ##################################### | 100%
# mkl-2022.1.0         | 129.7 MB  | ########################9             |  67%
#
# cudatoolkit-11.7.1   | 589.5 MB  | #####                                 |  14%
# mkl-2022.1.0         | 129.7 MB  | #########################9            |  70%
#
# cudatoolkit-11.7.1   | 589.5 MB  | #####2                                |  14%
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | 1                                     |   0%
# cudatoolkit-11.7.1   | 589.5 MB  | #####5                                |  15%
#
#
#
#
#
#
#
# p11-kit-0.24.1       | 4.5 MB    | #############################3        |  79%
# cudatoolkit-11.7.1   | 589.5 MB  | #####7                                |  15%
#
#
#
#
#
#
#
#
# intel-openmp-2022.0. | 4.2 MB    | 1                                     |   0%
# cudatoolkit-11.7.1   | 589.5 MB  | #####9                                |  16%
#
#
#
#
#
#
#
#
# intel-openmp-2022.0. | 4.2 MB    | ############################5         |  77%
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | 1                                     |   0%
# cudatoolkit-11.7.1   | 589.5 MB  | ######1                               |  17%
# cudatoolkit-11.7.1   | 589.5 MB  | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
# aom-3.5.0            | 2.7 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    | 2                                     |   1%
# cudatoolkit-11.7.1   | 589.5 MB  | ######7                               |  18%
# mkl-2022.1.0         | 129.7 MB  | ##################################2   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.9 MB    | 3                                     |   1%
# cudatoolkit-11.7.1   | 589.5 MB  | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #######6                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 821 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ########4                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.3.1       | 702 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ###########2                          |  30% [A
#
#
#
#
#
# torchaudio-2.0.2     | 7.3 MB    | ##################################### | 100%
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ###########7                          |  32%
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ###############5                      |  42%
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ################6                     |  45%
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #################3                    |  47%
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
#
# aom-3.5.0            | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ####################2                 |  55%
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #####################                 |  57%
#
#
#
#
#
#
#
#
#
# x265-3.5             | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.4.1        | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# svt-av1-1.4.1        | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libvpx-1.11.0        | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# x264-1!164.3095      | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #######################8              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.9.1         | 988 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.9.1         | 988 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 2.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ########################1             |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 821 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ########################5             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.7.9         | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpmath-1.3.0         | 834 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openh264-2.3.1       | 702 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | #########################2            |  68% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libx11-1.8.4    | 810 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cudatoolkit-11.7.1   | 589.5 MB  | ####################################7 |  99%
# cudatoolkit-11.7.1   | 589.5 MB  | ##################################### | 100%
#
# pytorch-2.0.1        | 86.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: / By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
#
# Note: you may need to restart the kernel to use updated packages.
# Channels:
#  - defaults
#  - conda-forge
#  - anaconda
#  - pytorch
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda/envs/jupyter_env
#
#   added / updated specs:
#     - librosa==0.10.0
#     - numpy==1.23.5
#     - pandas==1.5.3
#     - scikit-learn==1.2.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       3_kmp_llvm           7 KB  conda-forge
#     appdirs-1.4.4              |     pyhd3eb1b0_0          12 KB
#     audioread-3.0.1            |  py310hff52083_2          36 KB  conda-forge
#     contourpy-1.3.1            |  py310hdb19cb5_0         262 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     fonttools-4.55.3           |  py310h5eee18b_0         2.4 MB
#     joblib-1.4.2               |  py310h06a4308_0         401 KB
#     kiwisolver-1.4.8           |  py310h6a678d5_0          71 KB
#     lazy_loader-0.4            |  py310h06a4308_0          20 KB
#     libblas-3.9.0              |   20_linux64_mkl          15 KB  conda-forge
#     libcblas-3.9.0             |   20_linux64_mkl          14 KB  conda-forge
#     liblapack-3.9.0            |   20_linux64_mkl          14 KB  conda-forge
#     libllvm14-14.0.6           |       hcd5def8_4        30.0 MB  conda-forge
#     librosa-0.10.0             |     pyhd8ed1ab_2         188 KB  conda-forge
#     llvm-openmp-20.1.1         |       h024ca30_1         3.0 MB  conda-forge
#     llvmlite-0.43.0            |  py310h6a678d5_1         3.8 MB
#     matplotlib-base-3.10.0     |  py310hbfdbfaf_0         7.3 MB
#     mkl-2023.2.0               |   h84fe81f_50496       156.8 MB  conda-forge
#     mkl-service-2.4.0          |  py310h5eee18b_2          68 KB
#     mkl_fft-1.3.11             |  py310h5eee18b_0         198 KB
#     mkl_random-1.2.8           |  py310h1128e8f_0         318 KB
#     msgpack-python-1.0.3       |  py310hd09550d_0         218 KB
#     networkx-3.3               |  py310h06a4308_0         2.5 MB
#     numba-0.60.0               |  py310h5dc88bb_0         4.2 MB  conda-forge
#     numpy-1.23.5               |  py310h5f9d8c6_1          10 KB
#     numpy-base-1.23.5          |  py310hb5e798b_1         6.1 MB
#     pandas-1.5.3               |  py310h1128e8f_0        12.0 MB
#     pooch-1.4.0                |     pyhd3eb1b0_0          41 KB
#     pyparsing-3.2.0            |  py310h06a4308_0         423 KB
#     pysoundfile-0.13.1         |     pyhd8ed1ab_0          30 KB  conda-forge
#     scikit-learn-1.2.2         |  py310h6a678d5_1         7.7 MB
#     scipy-1.15.2               |  py310h23a989f_1        22.4 MB
#     soxr-0.1.3                 |       h0b41bf4_3         128 KB  conda-forge
#     soxr-python-0.5.0.post1    |  py310hf71b8c6_1          89 KB  conda-forge
#     tbb-2021.8.0               |       hdb19cb5_0         1.6 MB
#     threadpoolctl-3.5.0        |  py310h2f386ee_0          43 KB
#     unicodedata2-15.1.0        |  py310h5eee18b_1         519 KB
#     ------------------------------------------------------------
#                                            Total:       263.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            pkgs/main/noarch::appdirs-1.4.4-pyhd3eb1b0_0
#   audioread          conda-forge/linux-64::audioread-3.0.1-py310hff52083_2
#   contourpy          pkgs/main/linux-64::contourpy-1.3.1-py310hdb19cb5_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/linux-64::fonttools-4.55.3-py310h5eee18b_0
#   joblib             pkgs/main/linux-64::joblib-1.4.2-py310h06a4308_0
#   kiwisolver         pkgs/main/linux-64::kiwisolver-1.4.8-py310h6a678d5_0
#   lazy_loader        pkgs/main/linux-64::lazy_loader-0.4-py310h06a4308_0
#   libllvm14          conda-forge/linux-64::libllvm14-14.0.6-hcd5def8_4
#   librosa            conda-forge/noarch::librosa-0.10.0-pyhd8ed1ab_2
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-20.1.1-h024ca30_1
#   llvmlite           pkgs/main/linux-64::llvmlite-0.43.0-py310h6a678d5_1
#   matplotlib-base    pkgs/main/linux-64::matplotlib-base-3.10.0-py310hbfdbfaf_0
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py310h5eee18b_2
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.11-py310h5eee18b_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.8-py310h1128e8f_0
#   msgpack-python     pkgs/main/linux-64::msgpack-python-1.0.3-py310hd09550d_0
#   numba              conda-forge/linux-64::numba-0.60.0-py310h5dc88bb_0
#   numpy-base         pkgs/main/linux-64::numpy-base-1.23.5-py310hb5e798b_1
#   pooch              pkgs/main/noarch::pooch-1.4.0-pyhd3eb1b0_0
#   pyparsing          pkgs/main/linux-64::pyparsing-3.2.0-py310h06a4308_0
#   pysoundfile        conda-forge/noarch::pysoundfile-0.13.1-pyhd8ed1ab_0
#   scikit-learn       pkgs/main/linux-64::scikit-learn-1.2.2-py310h6a678d5_1
#   scipy              pkgs/main/linux-64::scipy-1.15.2-py310h23a989f_1
#   soxr               conda-forge/linux-64::soxr-0.1.3-h0b41bf4_3
#   soxr-python        conda-forge/linux-64::soxr-python-0.5.0.post1-py310hf71b8c6_1
#   tbb                pkgs/main/linux-64::tbb-2021.8.0-hdb19cb5_0
#   threadpoolctl      pkgs/main/linux-64::threadpoolctl-3.5.0-py310h2f386ee_0
#   unicodedata2       pkgs/main/linux-64::unicodedata2-15.1.0-py310h5eee18b_1
#
# The following packages will be UPDATED:
#
#   libblas                              3.9.0-16_linux64_mkl --> 3.9.0-20_linux64_mkl
#   libcblas                             3.9.0-16_linux64_mkl --> 3.9.0-20_linux64_mkl
#   liblapack                            3.9.0-16_linux64_mkl --> 3.9.0-20_linux64_mkl
#   mkl                  pkgs/main::mkl-2022.1.0-hc2b9512_224 --> conda-forge::mkl-2023.2.0-h84fe81f_50496
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   numpy              conda-forge::numpy-2.1.0-py310hd6e36a~ --> pkgs/main::numpy-1.23.5-py310h5f9d8c6_1
#
# The following packages will be DOWNGRADED:
#
#   _openmp_mutex                                   4.5-2_gnu --> 4.5-3_kmp_llvm
#   networkx                            3.4.2-py310h06a4308_0 --> 3.3-py310h06a4308_0
#   pandas                              2.2.3-py310h6a678d5_0 --> 1.5.3-py310h1128e8f_0
#
#
#
# Downloading and Extracting Packages:
# mkl-2023.2.0         | 156.8 MB  |                                       |   0%
# libllvm14-14.0.6     | 30.0 MB   |                                       |   0%
#
# scipy-1.15.2         | 22.4 MB   |                                       |   0%
#
#
# pandas-1.5.3         | 12.0 MB   |                                       |   0%
#
#
#
# scikit-learn-1.2.2   | 7.7 MB    |                                       |   0%
#
#
#
#
# matplotlib-base-3.10 | 7.3 MB    |                                       |   0%
#
#
#
#
#
# numpy-base-1.23.5    | 6.1 MB    |                                       |   0%
#
#
#
#
#
#
# numba-0.60.0         | 4.2 MB    |                                       |   0%
#
#
#
#
#
#
#
# llvmlite-0.43.0      | 3.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# llvm-openmp-20.1.1   | 3.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# networkx-3.3         | 2.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.55.3     | 2.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# tbb-2021.8.0         | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 519 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 423 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.4.2         | 401 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.8     | 318 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 262 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# msgpack-python-1.0.3 | 218 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.3.11       | 198 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librosa-0.10.0       | 188 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soxr-0.1.3           | 128 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soxr-python-0.5.0.po | 89 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libllvm14-14.0.6     | 30.0 MB   | #4                                    |   4%
#
#
# pandas-1.5.3         | 12.0 MB   | ###7                                  |  10%
#
#
#
# mkl-2023.2.0         | 156.8 MB  |                                       |   0%
#
# scipy-1.15.2         | 22.4 MB   |                                       |   0%
# libllvm14-14.0.6     | 30.0 MB   | #######2                              |  20%
#
#
# mkl-2023.2.0         | 156.8 MB  | #                                     |   3%
#
# scipy-1.15.2         | 22.4 MB   | #######5                              |  20%
# libllvm14-14.0.6     | 30.0 MB   | ##############5                       |  39%
#
#
# mkl-2023.2.0         | 156.8 MB  | ##3                                   |   6%
#
# scipy-1.15.2         | 22.4 MB   | ##################2                   |  49%
# mkl-2023.2.0         | 156.8 MB  | ###9                                  |  11%
#
# scipy-1.15.2         | 22.4 MB   | ################################4     |  88%
# mkl-2023.2.0         | 156.8 MB  | #####8                                |  16%
#
#
#
#
# mkl-2023.2.0         | 156.8 MB  | #######3                              |  20%
#
#
#
#
#
#
#
# llvmlite-0.43.0      | 3.8 MB    | 1                                     |   0%
#
#
#
#
#
# numpy-base-1.23.5    | 6.1 MB    |                                       |   0%
#
#
#
#
#
#
# numba-0.60.0         | 4.2 MB    | 1                                     |   0%
#
#
#
#
# mkl-2023.2.0         | 156.8 MB  | ########5                             |  23%
#
#
#
#
#
# numpy-base-1.23.5    | 6.1 MB    | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.55.3     | 2.4 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.2.0         | 156.8 MB  | #########9                            |  27%
#
#
#
#
#
#
#
#
#
# networkx-3.3         | 2.5 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
# mkl-2023.2.0         | 156.8 MB  | ##############1                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 519 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.4.2         | 401 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.2.0         | 156.8 MB  | ###############7                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 262 KB    | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.8     | 318 KB    | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# msgpack-python-1.0.3 | 218 KB    | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.3.11       | 198 KB    | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librosa-0.10.0       | 188 KB    | ###1                                  |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soxr-python-0.5.0.po | 89 KB     | ######6                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.2.0         | 156.8 MB  | ##################3                   |  50% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.2.0         | 156.8 MB  | ##################################    |  92%
#
#
#
# mkl-2023.2.0         | 156.8 MB  | ####################################1 |  98%
#
#
# pandas-1.5.3         | 12.0 MB   | ##################################### | 100%
#
# scipy-1.15.2         | 22.4 MB   | ##################################### | 100%
# libllvm14-14.0.6     | 30.0 MB   | ##################################### | 100%
#
#
#
#
#
#
#
# llvmlite-0.43.0      | 3.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# llvmlite-0.43.0      | 3.8 MB    | ##################################### | 100%
#
#
#
#
# matplotlib-base-3.10 | 7.3 MB    | ##################################### | 100%
#
#
#
#
#
#
# numba-0.60.0         | 4.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# tbb-2021.8.0         | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
# numpy-base-1.23.5    | 6.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# tbb-2021.8.0         | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
# numba-0.60.0         | 4.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# llvm-openmp-20.1.1   | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# llvm-openmp-20.1.1   | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# networkx-3.3         | 2.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# networkx-3.3         | 2.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.55.3     | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.4.2         | 401 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# fonttools-4.55.3     | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# joblib-1.4.2         | 401 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 519 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 519 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# msgpack-python-1.0.3 | 218 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 262 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 423 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# msgpack-python-1.0.3 | 218 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.3.1      | 262 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.0      | 423 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.8     | 318 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librosa-0.10.0       | 188 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.3.11       | 198 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_random-1.2.8     | 318 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# librosa-0.10.0       | 188 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.3.11       | 198 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soxr-python-0.5.0.po | 89 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soxr-python-0.5.0.po | 89 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soxr-0.1.3           | 128 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.2.0         | 156.8 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: \
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !{sys.executable} -m pip install librosa
# Out:
# Requirement already satisfied: librosa in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: audioread>=2.1.9 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy>=1.20.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: soxr>=0.3.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: packaging in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from lazy-loader>=0.1->librosa) (24.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: requests in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pooch>=1.0->librosa) (2.32.3)
# Requirement already satisfied: appdirs in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (2025.1.31)

# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: audioread>=2.1.9 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy>=1.20.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: soxr>=0.3.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: packaging in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from lazy-loader>=0.1->librosa) (24.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: requests in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pooch>=1.0->librosa) (2.32.3)
# Requirement already satisfied: appdirs in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests->pooch>=1.0->librosa) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torchaudio
from torch.utils.data import Dataset, DataLoader
import glob
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, recall_score, roc_auc_score
import torchaudio.transforms as T
from torchvision.models import resnet18
import librosa
import warnings
warnings.filterwarnings('ignore')

# Dataset Analysis Function
def analyze_dataset(protocols_dir, audio_dir):
    """Analyze dataset characteristics including class balance and audio durations"""
    train_files = glob.glob(f"{protocols_dir}/train_fold*.csv")
    
    class_counts = [0, 0]
    durations = []
    sample_rates = set()
    valid_files = 0
    total_files = 0
    
    for fold_file in train_files:
        annos = pd.read_csv(fold_file)
        for idx in range(len(annos)):
            total_files += 1
            clip_name = annos.iloc[idx, 0]
            audio_path = os.path.join(audio_dir, f"{clip_name}.wav")
            
            if os.path.exists(audio_path):
                try:
                    metadata = torchaudio.info(audio_path)
                    duration = metadata.num_frames / metadata.sample_rate
                    durations.append(duration)
                    sample_rates.add(metadata.sample_rate)
                    
                    label = 0 if any(k in str(annos.iloc[idx, 1]).lower() for k in ['truth', '0']) else 1
                    class_counts[label] += 1
                    valid_files += 1
                except Exception as e:
                    print(f"Error analyzing {audio_path}: {e}")
    
    duration_stats = {
        'min': min(durations),
        'max': max(durations),
        'mean': np.mean(durations),
        'median': np.median(durations),
        'std': np.std(durations)
    }
    
    print("\nDataset Analysis Results:")
    print(f"Total files: {total_files}")
    print(f"Valid files: {valid_files} ({valid_files/total_files:.1%})")
    print(f"Class distribution: {class_counts} (Real: {class_counts[0]}, Fake: {class_counts[1]})")
    print(f"Class ratio: {class_counts[1]/class_counts[0]:.2f}:1")
    print(f"Sample rates found: {sample_rates}")
    print("Duration statistics (seconds):")
    for k, v in duration_stats.items():
        print(f"  {k}: {v:.2f}")
    
    return {
        'class_counts': class_counts,
        'duration_stats': duration_stats,
        'sample_rates': sample_rates,
        'valid_ratio': valid_files/total_files
    }

# Enhanced AudioDataset Class
class AudioDataset(Dataset):
    def __init__(self, annotations_file, audio_dir, target_length=16000, augmentations=False, 
                 use_spectrogram=False, spec_params=None):
        self.annos = pd.read_csv(annotations_file)
        self.audio_dir = audio_dir
        self.target_length = target_length
        self.augmentations = augmentations
        self.use_spectrogram = use_spectrogram
        
        self.spec_params = {
            'n_mels': 64,
            'n_fft': 1024,
            'hop_length': 512,
            'f_min': 20,
            'f_max': 8000
        }
        if spec_params:
            self.spec_params.update(spec_params)
        
        self.valid_data = []
        for idx in range(len(self.annos)):
            clip_name = self.annos.iloc[idx, 0]
            audio_path = os.path.join(self.audio_dir, f"{clip_name}.wav")
            if os.path.exists(audio_path):
                label = self._process_label(self.annos.iloc[idx, 1])
                self.valid_data.append((audio_path, label))
        
        print(f"Found {len(self.valid_data)}/{len(self.annos)} valid files.")
    
    def __len__(self):
        return len(self.valid_data)
    
    def __getitem__(self, idx):
        audio_path, label = self.valid_data[idx]
        try:
            waveform, sample_rate = torchaudio.load(audio_path)
            waveform = waveform.mean(dim=0)
            waveform = torchaudio.functional.resample(waveform, sample_rate, 16000)
            
            if waveform.shape[0] > self.target_length:
                start = torch.randint(0, waveform.shape[0] - self.target_length, (1,))
                waveform = waveform[start:start+self.target_length]
            else:
                padding = self.target_length - waveform.shape[0]
                waveform = torch.nn.functional.pad(waveform, (0, padding))
            
            if self.augmentations and torch.rand(1) < 0.5:
                waveform = self._apply_augmentations(waveform, sample_rate=16000)
            
            if self.use_spectrogram:
                spectrogram = self._create_spectrogram(waveform)
                return spectrogram.float(), torch.tensor(label)
            else:
                return waveform.float(), torch.tensor(label)
        except Exception as e:
            print(f"[ERROR] Error loading {audio_path}: {e}")
            return None, None
    def time_stretch(waveform, sample_rate, rate=1.0):
        # Convert tensor to numpy array
        waveform_np = waveform.numpy()
        
        # Apply time stretching
        stretched = librosa.effects.time_stretch(waveform_np, rate=rate)
        
        # Convert back to tensor
        return torch.from_numpy(stretched).float()
    
    def _create_spectrogram(self, waveform):
        mel_spec = T.MelSpectrogram(
            sample_rate=16000,
            n_mels=self.spec_params['n_mels'],
            n_fft=self.spec_params['n_fft'],
            hop_length=self.spec_params['hop_length'],
            f_min=self.spec_params['f_min'],
            f_max=self.spec_params['f_max']
        )(waveform)
        db_spec = T.AmplitudeToDB()(mel_spec)
        return db_spec.unsqueeze(0)
    
    def _process_label(self, label_str):
        str_label = str(label_str).strip().lower()
        return 0 if any(k in str_label for k in ['truth', '0']) else 1
    
    def _apply_augmentations(self, waveform, sample_rate):
        if torch.rand(1) < 0.3:
            mask_len = torch.randint(100, 1000, (1,)).item()
            start = torch.randint(0, max(1, waveform.shape[0] - mask_len), (1,))
            waveform[start:start+mask_len] = 0
        
        if torch.rand(1) < 0.3:
            noise = torch.randn(waveform.shape) * 0.01
            waveform = waveform + noise
        
        if torch.rand(1) < 0.3:
            n_steps = torch.randint(-3, 3, (1,)).item()
            waveform = torchaudio.functional.pitch_shift(waveform, sample_rate, n_steps)
        
        if torch.rand(1) < 0.3:
            rate = 0.8 + torch.rand(1).item() * 0.4
            waveform = torchaudio.functional.time_stretch(waveform, rate)
        
        if torch.rand(1) < 0.3:
            gain = 0.5 + torch.rand(1).item()
            waveform = T.Vol(gain=gain)(waveform)

        if torch.rand(1) < 0.3:
            rate = 0.8 + torch.rand(1).item() * 0.4  # Rate between 0.8 and 1.2
            try:
                waveform = time_stretch(waveform, sample_rate, rate)
            except Exception as e:
                print(f"Time stretching failed: {e}")
    
        return waveform

# Collate Function
def audio_collate_fn(batch):
    batch = [item for item in batch if item[0] is not None]
    if not batch:
        return torch.zeros(1, 16000), torch.tensor([0])
    inputs, labels = zip(*batch)
    if inputs[0].dim() == 3:
        inputs = torch.stack(inputs)
    else:
        inputs = torch.stack(inputs)
    labels = torch.stack(labels)
    return inputs, labels

# Compute Class Weights
def compute_class_weights(protocols_dir, audio_dir):
    train_files = glob.glob(f"{protocols_dir}/train_fold*.csv")
    labels = []
    for fold_file in train_files:
        annos = pd.read_csv(fold_file)
        for idx in range(len(annos)):
            clip_name = annos.iloc[idx, 0]
            audio_path = os.path.join(audio_dir, f"{clip_name}.wav")
            if os.path.exists(audio_path):
                label = 0 if any(k in str(annos.iloc[idx, 1]).lower() for k in ['truth', '0']) else 1
                labels.append(label)
    labels = np.array(labels)
    class_counts = np.bincount(labels)
    total = len(labels)
    weights = total / (2.0 * class_counts)
    return torch.tensor(weights, dtype=torch.float)

# Compute Metrics
def compute_metrics(preds, labels):
    preds = preds.argmax(dim=1).cpu().numpy()
    labels = labels.cpu().numpy()
    acc = accuracy_score(labels, preds)
    f1 = f1_score(labels, preds)
    recall = recall_score(labels, preds)
    auc = roc_auc_score(labels, preds)
    return acc, f1, recall, auc

# PANN CNN6 Model
class PANNCnn6(nn.Module):
    def __init__(self, num_classes=2, pretrained=True):
        super().__init__()
        
        # CNN6 architecture
        self.conv_block1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.conv_block2 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.conv_block3 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        self.conv_block4 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        
        # Adaptive pooling to handle variable input sizes
        self.adaptive_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc1 = nn.Linear(512, 512)
        self.fc2 = nn.Linear(512, num_classes)
        self.dropout = nn.Dropout(0.5)
        
        if pretrained:
            self._load_pretrained_weights()
    
    def _load_pretrained_weights(self):
        try:
            checkpoint = torch.hub.load_state_dict_from_url(
                'https://zenodo.org/record/3987831/files/Cnn6_mAP=0.343.pth',
                map_location='cpu' if not torch.cuda.is_available() else 'cuda'
            )
            state_dict = checkpoint['model']
            
            # Load weights for each block
            self._load_block_weights(self.conv_block1, state_dict, 'conv_block1')
            self._load_block_weights(self.conv_block2, state_dict, 'conv_block2')
            self._load_block_weights(self.conv_block3, state_dict, 'conv_block3')
            self._load_block_weights(self.conv_block4, state_dict, 'conv_block4')
            
            print("Successfully loaded pretrained PANN CNN6 weights")
        except Exception as e:
            print(f"Error loading pretrained weights: {e}")
    
    def _load_block_weights(self, block, state_dict, block_prefix):
        for name, param in block.named_parameters():
            if f'{block_prefix}.{name}' in state_dict:
                param.data = state_dict[f'{block_prefix}.{name}'].data
    
    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = self.conv_block4(x)
        
        # Use adaptive pooling to handle different input sizes
        x = self.adaptive_pool(x)
        x = x.view(x.size(0), -1)  # Flatten
        
        x = self.fc1(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x
# AST Model
class ASTModel(nn.Module):
    def __init__(self, patch_size=16, num_layers=6, num_heads=8, embed_dim=768, 
                 spectrogram_height=64, spectrogram_width=None):
        super().__init__()
        
        if isinstance(patch_size, int):
            patch_size = (patch_size, patch_size)
        
        self.patch_embed = nn.Conv2d(
            in_channels=1,
            out_channels=embed_dim,
            kernel_size=patch_size,
            stride=patch_size
        )
        
        output_height = (spectrogram_height - patch_size[0]) // patch_size[0] + 1
        output_width = (spectrogram_width - patch_size[1]) // patch_size[1] + 1
        num_patches = output_height * output_width
        
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches + 1, embed_dim))
        self.cls_token = nn.Parameter(torch.zeros(1, 1, embed_dim))
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=embed_dim, nhead=num_heads),
            num_layers=num_layers
        )
        self.classifier = nn.Linear(embed_dim, 2)
        self.dropout = nn.Dropout(0.1)
    
    def forward(self, x):
        x = self.patch_embed(x)
        x = x.flatten(2)
        x = x.transpose(1, 2)
        
        cls_tokens = self.cls_token.expand(x.shape[0], -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed
        x = self.dropout(x)
        x = self.transformer(x)
        return self.classifier(x[:, 0])

# ResNet Model with Dropout
class ResNetModel(nn.Module):
    def __init__(self, dropout=0.5):
        super().__init__()
        self.resnet = resnet18(pretrained=True)
        self.resnet.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        self.resnet.fc = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(512, 2)
        )
    
    def forward(self, x):
        return self.resnet(x)

# Training Function with Model Saving
def train_model(config):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using {device}")
    
    # Compute class weights if needed
    class_weights = None
    if config['class_weighting']:
        class_weights = compute_class_weights(config['protocols_dir'], config['audio_dir'])
        class_weights = class_weights.to(device)
        print(f"Class weights: {class_weights}")
    
    # Initialize model
    if config['model_type'] == 'pann':
        model = PANNCnn6(num_classes=2, pretrained=True).to(device)
    elif config['model_type'] == 'ast':
        target_length = config['target_length']
        spectrogram_width = ((target_length - config['spec_params']['n_fft']) // config['spec_params']['hop_length']) + 1
        model = ASTModel(
            patch_size=config.get('patch_size', 16),
            num_layers=config.get('num_layers', 6),
            num_heads=config.get('num_heads', 8),
            embed_dim=config.get('embed_dim', 768),
            spectrogram_height=config['spec_params']['n_mels'],
            spectrogram_width=spectrogram_width
        ).to(device)
    elif config['model_type'] == 'resnet':
        model = ResNetModel(dropout=config.get('dropout', 0.5)).to(device)
    
    # Create checkpoint directory
    os.makedirs(config['checkpoint_dir'], exist_ok=True)
    metrics_file = os.path.join(config['checkpoint_dir'], 'metrics.csv')
    if not os.path.exists(metrics_file):
        pd.DataFrame(columns=['epoch', 'fold', 'train_loss', 'train_acc', 'train_f1', 
                            'train_recall', 'train_auc', 'val_loss', 'val_acc', 
                            'val_f1', 'val_recall', 'val_auc']).to_csv(metrics_file, index=False)
    
    # Get fold numbers
    train_files = glob.glob(f"{config['protocols_dir']}/train_fold*.csv")   
    fold_numbers = sorted([f.split("train_fold")[1].split(".csv")[0] for f in train_files])
    
    for fold in fold_numbers:
        print(f"\n=== Training Fold {fold} ===")
        
        # Initialize fresh model for each fold
        if config['model_type'] == 'pann':
            model = PANNCnn6(num_classes=2, pretrained=True).to(device)
        elif config['model_type'] == 'ast':
            model = ASTModel(
                patch_size=config.get('patch_size', 16),
                num_layers=config.get('num_layers', 6),
                num_heads=config.get('num_heads', 8),
                embed_dim=config.get('embed_dim', 768),
                spectrogram_height=config['spec_params']['n_mels'],
                spectrogram_width=((config['target_length'] - config['spec_params']['n_fft']) // 
                                 config['spec_params']['hop_length']) + 1
            ).to(device)
        elif config['model_type'] == 'resnet':
            model = ResNetModel(dropout=config.get('dropout', 0.5)).to(device)
        
        optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'], weight_decay=1e-5)
        criterion = nn.CrossEntropyLoss(weight=class_weights) if config['class_weighting'] else nn.CrossEntropyLoss()
        
        scheduler = None
        if config['lr_scheduler']:
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)
        
        # Load data
        train_file = f"{config['protocols_dir']}/train_fold{fold}.csv"
        val_file = f"{config['protocols_dir']}/test_fold{fold}.csv"
        
        train_dataset = AudioDataset(
            train_file, config['audio_dir'], config['target_length'],
            config['augmentations'], config['use_spectrogram'], config.get('spec_params')
        )
        val_dataset = AudioDataset(
            val_file, config['audio_dir'], config['target_length'],
            False, config['use_spectrogram'], config.get('spec_params')
        )
        
        train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], 
                                collate_fn=audio_collate_fn, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=config['batch_size'],
                              collate_fn=audio_collate_fn)
        
        best_val_loss = float('inf')
        patience_counter = 0
        
        for epoch in range(config['num_epochs']):
            model.train()
            epoch_loss = 0
            train_preds, train_labels = [], []
            
            # Training loop
            for inputs, labels in train_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                
                epoch_loss += loss.item()
                train_preds.append(outputs.detach())
                train_labels.append(labels)
            
            # Validation loop
            model.eval()
            val_loss = 0
            val_preds, val_labels = [], []
            with torch.no_grad():
                for inputs, labels in val_loader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    outputs = model(inputs)
                    val_loss += criterion(outputs, labels).item()
                    val_preds.append(outputs)
                    val_labels.append(labels)
            
            # Compute metrics
            train_preds = torch.cat(train_preds)
            train_labels = torch.cat(train_labels)
            train_acc, train_f1, train_recall, train_auc = compute_metrics(train_preds, train_labels)
            train_loss = epoch_loss / len(train_loader)
            
            val_preds = torch.cat(val_preds)
            val_labels = torch.cat(val_labels)
            val_acc, val_f1, val_recall, val_auc = compute_metrics(val_preds, val_labels)
            val_loss = val_loss / len(val_loader)
            
            # Update learning rate
            if scheduler:
                scheduler.step(val_loss)
            
            # Save metrics
            metrics = {
                'epoch': epoch + 1,
                'fold': fold,
                'train_loss': train_loss,
                'train_acc': train_acc,
                'train_f1': train_f1,
                'train_recall': train_recall,
                'train_auc': train_auc,
                'val_loss': val_loss,
                'val_acc': val_acc,
                'val_f1': val_f1,
                'val_recall': val_recall,
                'val_auc': val_auc
            }
            pd.DataFrame([metrics]).to_csv(metrics_file, mode='a', header=False, index=False)
            
            # Early stopping and model saving
            if val_loss < best_val_loss - config['min_delta']:
                best_val_loss = val_loss
                patience_counter = 0
                
                # Save best model for this fold
                torch.save({
                    'epoch': epoch + 1,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'val_loss': val_loss,
                    'val_acc': val_acc,
                    'config': config
                }, os.path.join(config['checkpoint_dir'], f'best_model_fold{fold}.pth'))
                
                print(f"Fold {fold} Epoch {epoch+1}: New best model saved (val_loss: {val_loss:.4f})")
            else:
                patience_counter += 1
                if patience_counter >= config['patience']:
                    print(f"Early stopping triggered for fold {fold} at epoch {epoch + 1}")
                    break
            
            print(f"Fold {fold} Epoch {epoch+1}/{config['num_epochs']}: "
                  f"Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, "
                  f"Val Acc: {val_acc:.4f}")

# Main Execution
if __name__ == "__main__":
    # First analyze the dataset
    dataset_stats = analyze_dataset(
        protocols_dir='/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/train_protocol',
        audio_dir='/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files'
    )
    
    # Determine optimal target length based on analysis
    median_duration = dataset_stats['duration_stats']['median']
    target_length = min(int(median_duration * 16000), 88200)  # Max 5.5 seconds
    
    base_config = {
        'batch_size': 32,
        'num_epochs': 50,
        'learning_rate': 1e-4,
        'audio_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files',
        'protocols_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/train_protocol',
        'base_checkpoint_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/train_new/experiment2/',
        'target_length': target_length,
        'augmentations': True,
        'lr_scheduler': True,
        'class_weighting': True if dataset_stats['class_counts'][0] != dataset_stats['class_counts'][1] else False,
        'use_spectrogram': True,
        'early_stopping': True,
        'patience': 7,
        'min_delta': 0.001,
        'spec_params': {
            'n_mels': 64,
            'n_fft': 1024,
            'hop_length': 512,
            'f_min': 20,
            'f_max': 8000
        }
    }

    experiments = [
        {
            'name': 'pann_cnn6',
            'model_type': 'pann',
            'learning_rate': 5e-5
        },
        {
            'name': 'ast_deep',
            'model_type': 'ast',
            'num_layers': 12,
            'learning_rate': 1e-4
        },
        {
            'name': 'resnet_dropout',
            'model_type': 'resnet',
            'dropout': 0.5
        }
    ]

    for exp in experiments:
        config = base_config.copy()
        config.update(exp)
        config['checkpoint_dir'] = os.path.join(base_config['base_checkpoint_dir'], exp['name'])
        print(f"\nRunning experiment: {exp['name']}")
        print(f"Configuration: {config}")
        train_model(config)
# Out:
# Dataset Analysis Results:
# Total files: 3291
# Valid files: 2523 (76.7%)
# Class distribution: [1186, 1337] (Real: 1186, Fake: 1337)
# Class ratio: 1.13:1
# Sample rates found: {44100}
# Duration statistics (seconds):
#   min: 2.00
#   max: 1569.00
#   mean: 7.84
#   median: 5.00
#   std: 48.78
#
# Running experiment: pann_cnn6
# Configuration: {'batch_size': 32, 'num_epochs': 50, 'learning_rate': 5e-05, 'audio_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files', 'protocols_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/train_protocol', 'base_checkpoint_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/train_new/experiment2/', 'target_length': 80000, 'augmentations': True, 'lr_scheduler': True, 'class_weighting': True, 'use_spectrogram': True, 'early_stopping': True, 'patience': 7, 'min_delta': 0.001, 'spec_params': {'n_mels': 64, 'n_fft': 1024, 'hop_length': 512, 'f_min': 20, 'f_max': 8000}, 'name': 'pann_cnn6', 'model_type': 'pann', 'checkpoint_dir': '/home/azureuser/cloudfiles/code/Users/yashika22csu235/research/train_new/experiment2/pann_cnn6'}
# Using cpu
# Class weights: tensor([1.0637, 0.9435])
# Successfully loaded pretrained PANN CNN6 weights
#
# === Training Fold 1 ===
# Successfully loaded pretrained PANN CNN6 weights
# Found 826/1098 valid files.
# Found 435/548 valid files.
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_truth4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_lie15.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_lie11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP20_lie13.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_truth7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_truth11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP5_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_lie5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_truth3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP36_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_lie12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP11_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP26_lie18.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_lie9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_lie18.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP20_lie9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_truth5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_lie13.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_lie5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_truth_17.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_lie18.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie17.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP6_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP57_truth_25.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP57_truth_26.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP66_truth_15.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_lie_11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP17_truth3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth14.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP24_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth15.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_lie5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP65_truth_14.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP57_truth_4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP66_truth_1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP19_truth5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP11_lie8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP57_truth_27.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP6_lie2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP57_truth_3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_truth14.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_lie2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_truth_33.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP27_truth7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_truth4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP57_lie_21.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP10_truth3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie16.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP48_truth7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_lie9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_lie16.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_truth23.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_truth3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP75_true3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_lie10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_lie_15.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP2_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie15.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_lie10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_truth_13.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_lie_4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP20_lie10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP11_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP65_lie_12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_lie2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_lie_28.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth16.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP34_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP15_lie15.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_truth12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_lie_22.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_truth5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP2_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP38_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_lie11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP21_lie9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_truth5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_truth4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie16.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Fold 1 Epoch 1: New best model saved (val_loss: 0.6901)
# Fold 1 Epoch 1/50: Train Loss: 0.7008, Val Loss: 0.6901, Val Acc: 0.5678
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP21_lie5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_truth4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP4_lie9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP54_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP76_true11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_lie8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP2_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_truth_6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_true6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP63_truth_20.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP59_truth_1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP32_lie12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP10_lie5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_lie_13.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP33_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP27_truth9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_truth3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_lie_22.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_truth3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_truth5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP2_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_truth7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP4_truth4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_lie5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP34_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP36_lie9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP9_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP61_truth_13.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_truth5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP37_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP17_lie8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_lie13.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_lie_16.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP12_truth4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie20.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP43_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie15.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie15.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_truth_12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP34_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP35_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# ...
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP66_truth_4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP25_lie8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP27_lie2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP48_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_lie_21.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP24_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP19_truth4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_lie2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_truth4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_lie2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP23_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_truth5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP24_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_truth_9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP16_lie4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ lie2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP6_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP14_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_truth5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP45_truth4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_truth_7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP28_truth14.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP50_lie10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP29_truth5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_lie_26.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie11.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP75_true2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP65_truth_5.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_lie_9.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_true4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP3_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP7_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP20_truth3.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP47_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP58_lie_26.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP11_lie10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP42_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP31_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP18_lie10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP10_truth1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP11_lie12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP1_truth7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP53_lie1.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP5_truth10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_truth7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP55_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/SB_WILTY_EP41_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_truth6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP49_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP65_lie_12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_lie_27.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP46_truth8.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP56_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP44_lie2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP72_lie13.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP13_truth2.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP52_lie7.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/LS_WILTY_EP73_ true16.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Time stretching failed: name 'time_stretch' is not defined
# Time stretching failed: name 'time_stretch' is not defined
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_4.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP62_truth_10.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/YW_WILTY_EP51_lie6.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP64_lie_21.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/AN_WILTY_EP22_lie21.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# [ERROR] Error loading /home/azureuser/cloudfiles/code/Users/yashika22csu235/research/audio_files/BRI_WILTY_EP60_truth_12.wav: module 'torchaudio.functional' has no attribute 'time_stretch'
# Early stopping triggered for fold 3 at epoch 9
